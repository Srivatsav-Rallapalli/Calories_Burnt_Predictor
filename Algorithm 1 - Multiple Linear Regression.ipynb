# %%
import pandas as pd

import warnings
warnings.simplefilter('ignore')

# %%
# Importing the dataset.

df = pd.read_csv(r'clean.csv')
df
# Out:
#        Age  Heart_Rate  Calories  Gender_male
# 0       68       105.0     231.0            1
# 1       20        94.0      66.0            0
# 2       69        88.0      26.0            1
# 3       34       100.0      71.0            0
# 4       27        81.0      35.0            0
# ...    ...         ...       ...          ...
# 14995   20        92.0      45.0            0
# 14996   27        85.0      23.0            0
# 14997   43        90.0      75.0            0
# 14998   78        84.0      11.0            1
# 14999   63        92.0      98.0            1
#
# [15000 rows x 4 columns]

# %%
# Seperating the Dependent and Independent variables.

X = df.drop(columns=['Calories'])
y = df['Calories']

# %%
# Splitting the data into train and test.

from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(X,y,random_state=42,train_size=0.8)

# %%
# Building the Linear REgression model.

from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(x_train,y_train)

print('Intercept value is :',model.intercept_)
print('Coefficient value is :',model.coef_)
# Out:
# Intercept value is : -491.2617226352439
# Coefficient value is : [0.52525311 5.83770616 1.12754257]

# %%
# Predicting on the train data

ypred_train = model.predict(x_train)

# calculating the train r2 score and cross validation score

from sklearn.metrics import r2_score
print('Train r2 score is :',r2_score(y_train,ypred_train))

from sklearn.model_selection import cross_val_score
print('Cross validation score is :',cross_val_score(model,x_train,y_train,cv=5).mean())

# Predicting on test data

ypred_test = model.predict(x_test)

# calculating the test r2 score

print('Test r2 score is :',r2_score(y_test,ypred_test))
# Out:
# Train r2 score is : 0.8259348090204159
# Cross validation score is : 0.8253414765235016
# Test r2 score is : 0.8325081255896059

# %%
from sklearn.model_selection import train_test_split
df_train,df_test = train_test_split(df,train_size=0.8,random_state=42)

import statsmodels.formula.api as smf
model1 = smf.ols('y_train~x_train',data=df_train).fit()
model1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                y_train   R-squared:                       0.826
# Model:                            OLS   Adj. R-squared:                  0.826
# Method:                 Least Squares   F-statistic:                 1.897e+04
# Date:                Wed, 11 Dec 2024   Prob (F-statistic):               0.00
# Time:                        13:50:15   Log-Likelihood:                -56097.
# No. Observations:               12000   AIC:                         1.122e+05
# Df Residuals:                   11996   BIC:                         1.122e+05
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   -491.2617      2.458   -199.884      0.000    -496.079    -486.444
# x_train[0]     0.5253      0.014     37.583      0.000       0.498       0.553
# x_train[1]     5.8377      0.025    235.114      0.000       5.789       5.886
# x_train[2]     1.1275      0.474      2.380      0.017       0.199       2.056
# ==============================================================================
# Omnibus:                        0.529   Durbin-Watson:                   2.003
# Prob(Omnibus):                  0.767   Jarque-Bera (JB):                0.544
# Skew:                          -0.015   Prob(JB):                        0.762
# Kurtosis:                       2.988   Cond. No.                     1.09e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.09e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# - The p-value of every variable is < 0.05 which means Regression model is fitted.
